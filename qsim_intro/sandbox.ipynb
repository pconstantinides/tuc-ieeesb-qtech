# %%
import numpy as np
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit
from qiskit.circuit import Parameter

# %%
qc = QuantumCircuit(4)
theta = Parameter('θ')

qc.h([0, 1, 3])
qc.cx(0, 1)
qc.cx(1, 2)
qc.cx(2, 3)
qc.rz(theta, 3)
qc.cx(2, 3)
qc.cx(1, 2)
qc.cx(0, 1)
qc.h([0, 1, 3])

# %%
qc.draw('mpl', style="textbook")
